# %%
import pandas as pd

# %%
data1 = pd.read_excel('Keyword dummy data.xlsx')
data2 = pd.read_excel('Sponsored Products Advertised product report.xlsx')
data3 = pd.read_excel('keyword sheets.xlsx')
data4 = pd.read_csv('keywords_cleaned_patial.csv')
data1.info(), data2.info(), data3.info(), data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1551 entries, 0 to 1550
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      1551 non-null   datetime64[ns]
#  1   Portfolio name                            1551 non-null   object
#  2   Currency                                  1551 non-null   object
#  3   Campaign Name                             1551 non-null   object
#  4   Ad Group Name                             1551 non-null   object
#  5   Targeting                                 1551 non-null   object
#  6   Match Type                                1551 non-null   object
#  7   Impressions                               1551 non-null   int64
#  8   Clicks                                    1551 non-null   int64
#  9   Click-Thru Rate (CTR)                     1545 non-null   float64
#  10  Bid Value                                 714 non-null    float64
#  11  Suggested lower bid range                 714 non-null    float64
#  12  Suggested upper bid range                 714 non-null    float64
#  13  Spend                                     1551 non-null   float64
#  14  Total Advertising Cost of Sales (ACoS)    113 non-null    float64
#  15  Total Return on Advertising Spend (RoAS)  496 non-null    float64
#  16  14 Day Total Sales (₹)                    1551 non-null   float64
#  17  14 Day Total Orders (#)                   1551 non-null   int64
#  18  14 Day Total Units (#)                    1551 non-null   int64
#  19  14 Day Conversion Rate                    496 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(4), object(6)
# memory usage: 242.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      265 non-null    datetime64[ns]
#  1   Portfolio name                            265 non-null    object
#  2   Currency                                  265 non-null    object
#  3   Campaign Name                             265 non-null    object
#  4   Ad Group Name                             265 non-null    object
#  5   Advertised ASIN                           265 non-null    object
#  6   Impressions                               265 non-null    float64
#  7   Clicks                                    265 non-null    float64
#  8   Click-Thru Rate (CTR)                     265 non-null    float64
#  9   Cost Per Click (CPC)                      187 non-null    float64
#  10  Spend                                     265 non-null    float64
#  11  14 Day Total Sales (₹)                    265 non-null    float64
#  12  Total Advertising Cost of Sales (ACoS)    72 non-null     float64
#  13  Total Return on Advertising Spend (RoAS)  187 non-null    float64
#  14  14 Day Total Orders (#)                   265 non-null    float64
#  15  14 Day Total Units (#)                    265 non-null    float64
#  16  14 Day Conversion Rate                    187 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(5)
# memory usage: 35.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 888 entries, 0 to 887
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      888 non-null    datetime64[ns]
#  1   Portfolio name                            888 non-null    object
#  2   Currency                                  888 non-null    object
#  3   Campaign Name                             888 non-null    object
#  4   Ad Group Name                             888 non-null    object
#  5   Targeting                                 888 non-null    object
#  6   Match Type                                888 non-null    object
#  7   Impressions                               888 non-null    float64
#  8   Clicks                                    888 non-null    float64
#  9   Click-Thru Rate (CTR)                     886 non-null    float64
#  10  Bid Value                                 888 non-null    object
#  11  Suggested lower bid range                 888 non-null    object
#  12  Suggested upper bid range                 888 non-null    object
#  13  Spend                                     888 non-null    object
#  14  Total Advertising Cost of Sales (ACoS)    104 non-null    float64
#  15  Total Return on Advertising Spend (RoAS)  396 non-null    float64
#  16  14 Day Total Sales (₹)                    888 non-null    object
#  17  14 Day Total Orders (#)                   888 non-null    float64
#  18  14 Day Total Units (#)                    888 non-null    float64
#  19  14 Day Conversion Rate                    396 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(11)
# memory usage: 138.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      594 non-null    object
#  1   Portfolio name                            594 non-null    object
#  2   Currency                                  594 non-null    object
#  3   Campaign Name                             594 non-null    object
#  4   Ad Group Name                             594 non-null    object
#  5   Targeting                                 594 non-null    object
#  6   Match Type                                594 non-null    object
#  7   Impressions                               594 non-null    int64
#  8   Clicks                                    594 non-null    int64
#  9   Click-Thru Rate (CTR)                     594 non-null    float64
#  10  Bid Value                                 594 non-null    object
#  11  Suggested lower bid range                 594 non-null    object
#  12  Suggested upper bid range                 594 non-null    object
#  13  Spend                                     594 non-null    object
#  14  Total Advertising Cost of Sales (ACoS)    594 non-null    float64
#  15  Total Return on Advertising Spend (RoAS)  594 non-null    float64
#  16  14 Day Total Sales (₹)                    594 non-null    object
#  17  14 Day Total Orders (#)                   594 non-null    int64
#  18  14 Day Total Units (#)                    594 non-null    int64
#  19  14 Day Conversion Rate                    594 non-null    float64
# dtypes: float64(4), int64(4), object(12)
# memory usage: 92.9+ KB
# (None, None, None, None)

# %%
set.intersection(set(data1.columns), set(data2.columns), set(data3.columns), set(data4.columns))
# Out:
# {'14 Day Conversion Rate',
#  '14 Day Total Orders (#)',
#  '14 Day Total Sales (₹)',
#  '14 Day Total Units (#)',
#  'Ad Group Name',
#  'Campaign Name',
#  'Click-Thru Rate (CTR)',
#  'Clicks',
#  'Currency',
#  'Date',
#  'Impressions',
#  'Portfolio name',
#  'Spend',
#  'Total Advertising Cost of Sales (ACoS)',
#  'Total Return on Advertising Spend (RoAS)'}

# %%
common_features = set.intersection(set(data1.columns), set(data3.columns), set(data4.columns)) - set('Date')

# %%
data = pd.concat([data1[common_features], data3[common_features], data4[common_features]]).drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3033 entries, 0 to 593
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Portfolio name                            3033 non-null   object
#  1   Bid Value                                 2196 non-null   object
#  2   Suggested lower bid range                 2196 non-null   object
#  3   Impressions                               3033 non-null   float64
#  4   Targeting                                 3033 non-null   object
#  5   Match Type                                3033 non-null   object
#  6   Ad Group Name                             3033 non-null   object
#  7   Currency                                  3033 non-null   object
#  8   Date                                      3033 non-null   object
#  9   14 Day Conversion Rate                    1486 non-null   float64
#  10  Suggested upper bid range                 2196 non-null   object
#  11  14 Day Total Sales (₹)                    3033 non-null   object
#  12  14 Day Total Orders (#)                   3033 non-null   float64
#  13  Spend                                     3033 non-null   object
#  14  Click-Thru Rate (CTR)                     3025 non-null   float64
#  15  Total Return on Advertising Spend (RoAS)  1486 non-null   float64
#  16  Total Advertising Cost of Sales (ACoS)    811 non-null    float64
#  17  14 Day Total Units (#)                    3033 non-null   float64
#  18  Clicks                                    3033 non-null   float64
#  19  Campaign Name                             3033 non-null   object
# dtypes: float64(8), object(12)
# memory usage: 497.6+ KB

# %%
data = data.drop(columns=['Total Advertising Cost of Sales (ACoS)']).dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1486 entries, 0 to 593
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Portfolio name                            1486 non-null   object
#  1   Bid Value                                 1486 non-null   object
#  2   Suggested lower bid range                 1486 non-null   object
#  3   Impressions                               1486 non-null   float64
#  4   Targeting                                 1486 non-null   object
#  5   Match Type                                1486 non-null   object
#  6   Ad Group Name                             1486 non-null   object
#  7   Currency                                  1486 non-null   object
#  8   Date                                      1486 non-null   object
#  9   14 Day Conversion Rate                    1486 non-null   float64
#  10  Suggested upper bid range                 1486 non-null   object
#  11  14 Day Total Sales (₹)                    1486 non-null   object
#  12  14 Day Total Orders (#)                   1486 non-null   float64
#  13  Spend                                     1486 non-null   object
#  14  Click-Thru Rate (CTR)                     1486 non-null   float64
#  15  Total Return on Advertising Spend (RoAS)  1486 non-null   float64
#  16  14 Day Total Units (#)                    1486 non-null   float64
#  17  Clicks                                    1486 non-null   float64
#  18  Campaign Name                             1486 non-null   object
# dtypes: float64(7), object(12)
# memory usage: 232.2+ KB

# %%
data.head()
# Out:
#    Portfolio name  Bid Value Suggested lower bid range  Impressions  \
# 0     Not grouped      31.35                 14.788293         14.0
# 29    Not grouped      37.44                 10.510025        557.0
# 30    Not grouped  37.485714                 13.985688        621.0
# 31    Not grouped      43.27                 35.906685        526.0
# 32    Not grouped      44.39                  8.772781        484.0
#
#           Targeting Match Type                Ad Group Name Currency  \
# 0     knee pain oil      EXACT  Pain Relief Oil -SP-Generic      INR
# 29  pain relief oil      EXACT  Pain Relief Oil -SP-Generic      INR
# 30  pain relief oil      EXACT  Pain Relief Oil -SP-Generic      INR
# 31  pain relief oil      EXACT  Pain Relief Oil -SP-Generic      INR
# 32  pain relief oil      EXACT  Pain Relief Oil -SP-Generic      INR
#
#                    Date  14 Day Conversion Rate Suggested upper bid range  \
# 0   2020-02-01 00:00:00                0.000000                   36.2406
# 29  2020-02-01 00:00:00                0.000000                 32.595049
# 30  2020-02-02 00:00:00                0.142857                 27.390972
# 31  2020-02-03 00:00:00                0.000000                 22.005446
# 32  2020-02-04 00:00:00                0.000000                  2.766585
#
#    14 Day Total Sales (₹)  14 Day Total Orders (#)   Spend  \
# 0                     0.0                      0.0   31.35
# 29                    0.0                      0.0   37.44
# 30                 320.54                      1.0   262.4
# 31                    0.0                      0.0   43.27
# 32                    0.0                      0.0  177.56
#
#     Click-Thru Rate (CTR)  Total Return on Advertising Spend (RoAS)  \
# 0                0.071429                                   0.00000
# 29               0.001795                                   0.00000
# 30               0.011272                                   1.22157
# 31               0.001901                                   0.00000
# 32               0.008264                                   0.00000
#
#     14 Day Total Units (#)  Clicks  \
# 0                      0.0     1.0
# 29                     0.0     1.0
# 30                     1.0     7.0
# 31                     0.0     1.0
# 32                     0.0     4.0
#
#                                       Campaign Name
# 0   Pain relief Oil || SP || Generic || 22nd Nov'19
# 29  Pain relief Oil || SP || Generic || 22nd Nov'19
# 30  Pain relief Oil || SP || Generic || 22nd Nov'19
# 31  Pain relief Oil || SP || Generic || 22nd Nov'19
# 32  Pain relief Oil || SP || Generic || 22nd Nov'19

# %%
data['Total Return on Advertising Spend (RoAS)']
# Out:
# 0      0.00000
# 29     0.00000
# 30     1.22157
# 31     0.00000
# 32     0.00000
#         ...
# 589    0.00000
# 590    0.00000
# 591    0.00000
# 592    0.15000
# 593    0.20000
# Name: Total Return on Advertising Spend (RoAS), Length: 1486, dtype: float64

# %%
num_features = ['Bid Value', 'Suggested lower bid range', 'Suggested upper bid range',
                'Impressions', 'Spend', 'Click-Thru Rate (CTR)', 
                'Total Return on Advertising Spend (RoAS)', 'Clicks']

cat_features = ['Targeting', 'Match Type']

data['Bid Value'] = [float(str(val).split(' ')[-1]) for val in data['Bid Value']]
data['Suggested lower bid range'] = [float(str(val).split(' ')[-1]) for val in data['Suggested lower bid range']]
data['Suggested upper bid range'] = [float(str(val).split(' ')[-1]) for val in data['Suggested upper bid range']]
data['Spend'] = [float(str(val).replace(',', '').split(' ')[-1]) for val in data['Spend']]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1486 entries, 0 to 593
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Portfolio name                            1486 non-null   object
#  1   Bid Value                                 1486 non-null   float64
#  2   Suggested lower bid range                 1486 non-null   float64
#  3   Impressions                               1486 non-null   float64
#  4   Targeting                                 1486 non-null   object
#  5   Match Type                                1486 non-null   object
#  6   Ad Group Name                             1486 non-null   object
#  7   Currency                                  1486 non-null   object
#  8   Date                                      1486 non-null   object
#  9   14 Day Conversion Rate                    1486 non-null   float64
#  10  Suggested upper bid range                 1486 non-null   float64
#  11  14 Day Total Sales (₹)                    1486 non-null   object
#  12  14 Day Total Orders (#)                   1486 non-null   float64
#  13  Spend                                     1486 non-null   float64
#  14  Click-Thru Rate (CTR)                     1486 non-null   float64
#  15  Total Return on Advertising Spend (RoAS)  1486 non-null   float64
#  16  14 Day Total Units (#)                    1486 non-null   float64
#  17  Clicks                                    1486 non-null   float64
#  18  Campaign Name                             1486 non-null   object
# dtypes: float64(11), object(8)
# memory usage: 232.2+ KB

# %%
data = data[num_features + cat_features]
print(data.shape)
data.head(20)
# Out:
# (1486, 10)
#     Bid Value  Suggested lower bid range  Suggested upper bid range  \
# 0   31.350000                  14.788293                  36.240600
# 29  37.440000                  10.510025                  32.595049
# 30  37.485714                  13.985688                  27.390972
# 31  43.270000                  35.906685                  22.005446
# 32  44.390000                   8.772781                   2.766585
# 33  38.660000                  20.759459                  26.437317
# 35  41.460000                  31.074335                  51.360425
# 36  24.875000                  13.330754                  12.292197
# 37  30.415000                  24.893852                  25.096895
# 38  35.125000                  25.526453                  25.322579
# 39  13.740000                   8.446558                   6.325246
# 40  29.280000                   2.772386                  55.431571
# 41  43.040000                  39.765654                  25.673274
# 42  42.295000                   7.360665                  78.217556
# 43  42.455000                  34.203732                  40.800548
# 44  39.840000                   8.548132                  58.090416
# 45  38.613333                  30.719082                  48.782606
# 46  30.460000                  26.480759                   2.417558
# 47  38.137500                  12.604330                   3.386449
# 48  27.305000                  17.181170                   1.595547
#
#     Impressions   Spend  Click-Thru Rate (CTR)  \
# 0          14.0   31.35               0.071429
# 29        557.0   37.44               0.001795
# 30        621.0  262.40               0.011272
# 31        526.0   43.27               0.001901
# 32        484.0  177.56               0.008264
# 33        581.0   38.66               0.001721
# 35        665.0   82.92               0.003008
# 36       1063.0   99.50               0.003763
# 37        913.0   60.83               0.002191
# 38        684.0  210.75               0.008772
# 39        487.0   13.74               0.002053
# 40        717.0   58.56               0.002789
# 41        679.0   43.04               0.001473
# 42        455.0   84.59               0.004396
# 43        519.0  169.82               0.007707
# 44        624.0   39.84               0.001603
# 45        545.0  115.84               0.005505
# 46        721.0   60.92               0.002774
# 47        669.0  152.55               0.005979
# 48        540.0   54.61               0.003704
#
#     Total Return on Advertising Spend (RoAS)  Clicks        Targeting  \
# 0                                   0.000000     1.0    knee pain oil
# 29                                  0.000000     1.0  pain relief oil
# 30                                  1.221570     7.0  pain relief oil
# 31                                  0.000000     1.0  pain relief oil
# 32                                  0.000000     4.0  pain relief oil
# 33                                  0.000000     1.0  pain relief oil
# 35                                  0.000000     2.0  pain relief oil
# 36                                  3.221508     4.0  pain relief oil
# 37                                  0.000000     2.0  pain relief oil
# 38                                  0.000000     6.0  pain relief oil
# 39                                  0.000000     1.0  pain relief oil
# 40                                  5.473702     2.0  pain relief oil
# 41                                  0.000000     1.0  pain relief oil
# 42                                  0.000000     2.0  pain relief oil
# 43                                  0.000000     4.0  pain relief oil
# 44                                  0.000000     1.0  pain relief oil
# 45                                  0.000000     3.0  pain relief oil
# 46                                  0.000000     2.0  pain relief oil
# 47                                  0.000000     4.0  pain relief oil
# 48                                  0.000000     2.0  pain relief oil
#
#    Match Type
# 0       EXACT
# 29      EXACT
# 30      EXACT
# 31      EXACT
# 32      EXACT
# 33      EXACT
# 35      EXACT
# 36      EXACT
# 37      EXACT
# 38      EXACT
# 39      EXACT
# 40      EXACT
# 41      EXACT
# 42      EXACT
# 43      EXACT
# 44      EXACT
# 45      EXACT
# 46      EXACT
# 47      EXACT
# 48      EXACT

# %%
set(data['Targeting'])
# Out:
# {'anti aging cream',
#  'anti aging night cream',
#  'anti wrinkle cream',
#  'artho pain oil',
#  'arthritis oil',
#  'back pain oil',
#  'bhringraj hair oil',
#  'bhringraj oil',
#  'bhringraj oil for hair growth',
#  'close-match',
#  'evver night cream',
#  'evver sunscreen',
#  'evver uv guard',
#  'hair oil',
#  'joint pain massage oil',
#  'joint pain oil ayurvedic',
#  'joint pain relief',
#  'knee massage oil',
#  'knee oil',
#  'knee oil for pain',
#  'knee pain oil',
#  'knee pain relief',
#  'knee pain relief oil',
#  'knee pain relief products',
#  'leg pain medicine',
#  'leg pain relief oil',
#  'loose-match',
#  'muscle pain',
#  'muscle pain massage oil',
#  'muscle pain relief',
#  'muscle pain relief oil',
#  'muscle relief oil',
#  'night cream',
#  'oil joint pain',
#  'oil joint pain relief',
#  'oil leg pain',
#  'oil muscle pain',
#  'ortho oil',
#  'pain oil',
#  'pain relief massage oil',
#  'pain relief oil',
#  'pain relief oil natural',
#  'pain relieving oil',
#  'rhuval oil',
#  'rhuval oil joint pain',
#  'spf 50',
#  'substitutes',
#  'sunscreen',
#  'sunscreen cream',
#  'sunscreen spf 50',
#  'vitamin e oil',
#  'vitamin e oil hair'}

# %%
data.describe()
# Out:
#          Bid Value  Suggested lower bid range  Suggested upper bid range  \
# count  1486.000000                1486.000000                1486.000000
# mean     25.413346                  12.412437                  26.200636
# std      18.043107                  13.155040                  28.988057
# min       1.000000                   0.030000                   0.010000
# 25%      12.992500                   2.410000                   5.950000
# 50%      25.050000                   8.556172                  20.350000
# 75%      33.620000                  17.278899                  36.240000
# max      99.210000                  73.990000                 162.900000
#
#         Impressions        Spend  Click-Thru Rate (CTR)  \
# count   1486.000000  1486.000000            1486.000000
# mean     799.890310    68.026830               0.081101
# std     2065.826057   199.485955               0.197210
# min        0.000000     0.000000               0.000000
# 25%       13.000000     0.000000               0.000000
# 50%       73.000000    16.795000               0.002805
# 75%      562.000000    49.602500               0.020548
# max    13532.000000  2068.440000               1.000000
#
#        Total Return on Advertising Spend (RoAS)       Clicks
# count                               1486.000000  1486.000000
# mean                                  12.899004     2.936743
# std                                   64.628698     5.643867
# min                                    0.000000     0.000000
# 25%                                    0.000000     0.000000
# 50%                                    0.000000     1.000000
# 75%                                    0.000000     3.000000
# max                                  873.531136    48.000000
